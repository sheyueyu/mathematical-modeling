# %%
#导入需要的库
import pandana, matplotlib.pyplot as plt
from pandana.loaders import osm
# %matplotlib inline
import pandas as pd
import pandana as pdna

# %%
import geopandas

# %%
# # 利用OSM的api获取指定区域内的POI信息
# bbox = [30.1398, 120.85,31.89, 122.20] #上海的经纬度范围
# amenity = 'school' #兴趣点种类
# pois = osm.node_query(bbox[0], bbox[1], bbox[2], bbox[3], tags='"amenity"="{}"'.format(amenity))
# pois.to_csv("{}.csv".format(amenity),index=False, encoding='utf-8')

# %% [markdown]
# ## 确定研究范围的边界（经济技术开发区3-4环）

# %%
# bbox = [30.43,113.8932,30.6231,114.3107]   #经开区研究范围的大致经纬度，GCj-02坐标系
# landuse = 'residential'  
# pois = osm.node_query(bbox[0], bbox[1], bbox[2], bbox[3], tags='"landuse"="{}"'.format(landuse))
# pois.to_csv("{}.csv".format(landuse),index=False, encoding='utf-8')
"""
还是不要用这个获取兴趣点，这个poi不是很准确

"""
# Out:
# '\n还是不要用这个获取兴趣点，这个poi不是很准确\n\n'

# %% [markdown]
# ## 根据给定的经纬度范围，利用OSM下载区域内路网

# %%
bbox = [30.43,113.8932,30.6231,114.3107] #经开区的bbox

# %%
# network_filename='./jingkaiqu_net3.h5'#保存路网文件路径
# network = pandana.loaders.osm.pdna_network_from_bbox(bbox[0], bbox[1], bbox[2], bbox[3])

# %%
network = pandana.loaders.osm.pdna_network_from_bbox(bbox[0], bbox[1], bbox[2], bbox[3])
method = 'downloaded from OSM'

# identify nodes that are connected to fewer than some threshold of other nodes within a given distance
lcn = network.low_connectivity_nodes(impedance=1000, count=10, imp_name='distance')
#去除一些低连接度的节点，并保存路网文件
network.save_hdf5('./jingkaiqu_net4.h5', rm_nodes=lcn)
# Out:
# D:\ANACONDA\lib\site-packages\osmnet\load.py:445: FutureWarning: Assigning CRS to a GeoDataFrame without a geometry column is now deprecated and will not be supported in the future.
#   gdf.crs = crs
# D:\ANACONDA\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# D:\ANACONDA\lib\site-packages\osmnet\load.py:445: FutureWarning: Assigning CRS to a GeoDataFrame without a geometry column is now deprecated and will not be supported in the future.
#   gdf.crs = crs
# Requesting network data within bounding box from Overpass API in 1 request(s)
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](30.43000000,113.89320000,30.62310000,114.31070000);>;);out;'}"
# Downloaded 8,517.4KB from www.overpass-api.de in 70.09 seconds
# Downloaded OSM network data within bounding box from Overpass API in 1 request(s) and 70.21 seconds
# Returning OSM data with 68,892 nodes and 9,343 ways...
# Edge node pairs completed. Took 8.17 seconds
# Returning processed graph with 14,524 nodes and 21,665 edges...
# Completed OSM data download and Pandana node and edge table creation in 79.35 seconds

# %%
# # network = pandana.Network(network[0]["x"],network[0]["y"], network[1]["from"], network[1]["to"],network[1][["distance"]])
# network=pdna.Network(nodes["x"], nodes["y"], edges["from"], edges["to"],edges[["distance"]])

# %% [markdown]
# ### 导入路网和POI

# %%
#导入路网
network = pandana.network.Network.from_hdf5("./jingkaiqu_net_low3.h5")
#对路网进行预计算，方便后面的查询
distance = 2000  #距离是指计算的距离范围，如2000代表查询范围路网节点中2000m以内
network.precompute(distance + 1)#预计算
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-74-5b23dd166fce> in <module>
#       1 #导入路网
# ----> 2 network = pandana.network.Network.from_hdf5("./jingkaiqu_net_low3.h5")
#       3 #对路网进行预计算，方便后面的查询
#       4 distance = 2000  #距离是指计算的距离范围，如2000代表查询范围路网节点中2000m以内
#       5 network.precompute(distance + 1)#预计算
#
# D:\ANACONDA\lib\site-packages\pandana\network.py in from_hdf5(cls, filename)
#     117
#     118         """
# --> 119         return ph5.network_from_pandas_hdf5(cls, filename)
#     120
#     121     def save_hdf5(self, filename, rm_nodes=None):
#
# D:\ANACONDA\lib\site-packages\pandana\loaders\pandash5.py in network_from_pandas_hdf5(cls, filename)
#      77     return cls(
#      78         nodes['x'], nodes['y'], edges['from'], edges['to'], edges[imp_names],
# ---> 79         twoway=two_way)
#
# D:\ANACONDA\lib\site-packages\pandana\network.py in __init__(self, node_x, node_y, edge_from, edge_to, edge_weights, twoway)
#      70         nodes_df = pd.DataFrame({'x': node_x, 'y': node_y})
#      71         edges_df = pd.DataFrame({'from': edge_from, 'to': edge_to}).\
# ---> 72             join(edge_weights)
#      73
#      74         self.nodes_df = nodes_df
#
# D:\ANACONDA\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    8109         """
#    8110         return self._join_compat(
# -> 8111             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    8112         )
#    8113
#
# D:\ANACONDA\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    8141                 right_index=True,
#    8142                 suffixes=(lsuffix, rsuffix),
# -> 8143                 sort=sort,
#    8144             )
#    8145         else:
#
# D:\ANACONDA\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# D:\ANACONDA\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     682             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     683
# --> 684         join_index, left_indexer, right_indexer = self._get_join_info()
#     685
#     686         llabels, rlabels = _items_overlap_with_suffix(
#
# D:\ANACONDA\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
#     895         if self.left_index and self.right_index and self.how != "asof":
#     896             join_index, left_indexer, right_indexer = left_ax.join(
# --> 897                 right_ax, how=self.how, return_indexers=True, sort=self.sort
#     898             )
#     899         elif self.right_index and self.how == "left":
#
# D:\ANACONDA\lib\site-packages\pandas\core\indexes\base.py in join(self, other, how, level, return_indexers, sort)
#    3673         if not self.is_unique and not other.is_unique:
#    3674             return self._join_non_unique(
# -> 3675                 other, how=how, return_indexers=return_indexers
#    3676             )
#    3677         elif not self.is_unique or not other.is_unique:
#
# D:\ANACONDA\lib\site-packages\pandas\core\indexes\base.py in _join_non_unique(self, other, how, return_indexers)
#    3812
#    3813         left_idx, right_idx = get_join_indexers(
# -> 3814             [lvalues], [rvalues], how=how, sort=True
#    3815         )
#    3816
#
# D:\ANACONDA\lib\site-packages\pandas\core\reshape\merge.py in get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1439     }[how]
#    1440
# -> 1441     return join_func(lkey, rkey, count, **kwargs)
#    1442
#    1443
#
# pandas\_libs\join.pyx in pandas._libs.join.left_outer_join()
#
# MemoryError: Unable to allocate 2.47 TiB for an array with shape (339302436392,) and data type int64

# %%
import json
import ast

# %% [markdown]
# #### 导入poi

# %%
pois = pd.read_csv('./武汉市蔡甸区医院.csv')
pois.columns
# Out:
# Index(['Unnamed: 0', 'name', 'location', 'address', 'province', 'city', 'area',
#        'street_id', 'telephone', 'detail', 'uid'],
#       dtype='object')

# %%
df = pois
import ast
for i,v in df['location'].items(): #把str转换成dict
    v = ast.literal_eval(v)
    df['location'][i] = v
    
df['lat'] =pd.DataFrame(df.location.to_list())['lat']
df['lon'] =pd.DataFrame(df.location.to_list())['lng']
df
# Out:
# D:\ANACONDA\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#
#
# [85 rows x 13 columns]

# %%
pois = df

# %% [markdown]
# #### 对poi进行集计查询
# 集计给定距离范围内兴趣点属性，可以离散，可以是连续，取决于兴趣点的属性
# 如统计路网节点500内火锅店个数，是离散值统计
# 如统计路网节点500m内火锅店平均营业额，是连续值统计（需要知道每个火锅店的营业额）

# %% [markdown]
# #### 让poi与路网建立联系

# %%
x, y = pois['lon'],pois['lat']
node_ids = network.get_node_ids(x,y)
network.set(node_ids)  #set() 用一个与网络中节点相关的变量刻画城市空间

# %%
s = network.aggregate(2000, type="count", decay="linear") #聚合操作，比如计算1000m内的人口
"""
type = "count" 就是计数
decay = "linear" 即使线性
"""
fig_kwargs = {'figsize': [20, 20]}  #设置图形的大小
plot_kwargs = {'cmap': 'BrBG','s': 20,'edgecolor': 'none'}

sf_bbox = [30.43,113.8932,30.6231,114.3107]

fig,ax =network.plot(s, bbox=sf_bbox, 
         fig_kwargs=fig_kwargs, plot_kwargs=plot_kwargs,plot_type='scatter',
                     cbar_kwargs=None)
ax.set_facecolor('k')
plt.axis("off")
plt.show()

"""
cmap,热力图颜色

在pandana中，不再接收bmap_kwargs

plot_kwargs——用于控制颜色

'epsg': '4326'——指的是WGS48坐标

"""
# Out:
# "\ncmap,热力图颜色\n\n在pandana中，不再接收bmap_kwargs\n\nplot_kwargs——用于控制颜色\n\n'epsg': '4326'——指的是WGS48坐标\n\n"

# %%
import h5py
import numpy as np

# %%
f = h5py.File('./jingkaiqu_net3.h5','r')   #打开h5文件
# 可以查看所有的主键
for key in f.keys():
    print(f[key].name)
#     print(f[key].shape)
#     print(f[key].value)
# Out:
# /edges
# /impedance_names
# /nodes
# /two_way

# %%
edges =pd.read_hdf('./jingkaiqu_net3.h5','edges')   #读取边
print(edges)
"""
from 列中对应的是一个节点id
to 中对应的也是一个节点id
distance中是一个权重（距离）
"""
# Out:
#                              from          to    distance
# 286076008  3822581307   286076008  3822581307    9.419657
#            9440486696   286076008  9440486696   10.108185
# 286076143  1882284071   286076143  1882284071   18.331649
#            1926866245   286076143  1926866245  140.758848
# 286076166  1881981628   286076166  1881981628   12.137602
# ...                           ...         ...         ...
# 9614330239 8958991920  9614330239  8958991920  442.002980
# 9614330241 8958991929  9614330241  8958991929   27.824906
# 9614330255 7716138267  9614330255  7716138267  183.703109
#            8958991972  9614330255  8958991972   45.119501
# 9623169525 9067344126  9623169525  9067344126  141.167848
#
# [20848 rows x 3 columns]
# '\nfrom 列中对应的是一个节点id\nto 中对应的也是一个节点id\ndistance中是一个权重（距离）\n'

# %%
nodes =pd.read_hdf('./jingkaiqu_net_low.h5','nodes')   #读取节点
print(nodes)
# Out:
#                      x          y
# id
# 286076008   114.246416  30.611443
# 286076143   114.285625  30.595140
# 286076166   114.302132  30.598442
# 286085136   114.300235  30.594956
# 286085676   114.266004  30.599488
# ...                ...        ...
# 9520829248  114.289462  30.553067
# 9520829249  114.289360  30.553124
# 9520829255  114.291851  30.555675
# 9520829257  114.291946  30.555619
# 9520829258  114.292031  30.555569
#
# [13566 rows x 2 columns]
